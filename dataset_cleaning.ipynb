# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Prashanth\Downloads\superstore_dataset.csv")

df.head()
# Out:
#    Order ID  Order Date   Ship Date       Ship Mode     Customer Name  \
# 0  ORD-1001  2024-01-13  2024-01-19  Standard Class    Margaret Brown
# 1  ORD-1002  2024-01-16  2024-01-17  Standard Class           Amy Lee
# 2  ORD-1003  2024-01-04  2024-01-11    Second Class      Kelly Nelson
# 3  ORD-1004  2024-06-25  2024-06-30    Second Class  Benjamin Jimenez
# 4  ORD-1005  2024-10-22  2024-10-24     First Class   Stephanie Green
#
#        Segment Country           City   Region         Category Sub-Category  \
# 0  Home Office   India   Patrickmouth     East       Technology       Laptop
# 1  Home Office   India       Penaport  Central  Office Supplies        Paper
# 2     Consumer   India       Loriberg     East  Office Supplies          Pen
# 3     Consumer   India  Nathanchester    South        Furniture     Bookcase
# 4     Consumer   India  North Cynthia     East       Technology      Printer
#
#          Product Name   Sales  Quantity  Discount  Profit
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       200 non-null    str
#  1   Order Date     200 non-null    str
#  2   Ship Date      200 non-null    str
#  3   Ship Mode      200 non-null    str
#  4   Customer Name  200 non-null    str
#  5   Segment        200 non-null    str
#  6   Country        200 non-null    str
#  7   City           200 non-null    str
#  8   Region         200 non-null    str
#  9   Category       200 non-null    str
#  10  Sub-Category   200 non-null    str
#  11  Product Name   200 non-null    str
#  12  Sales          200 non-null    float64
#  13  Quantity       200 non-null    int64
#  14  Discount       200 non-null    float64
#  15  Profit         200 non-null    float64
# dtypes: float64(3), int64(1), str(12)
# memory usage: 25.1 KB

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# Region           0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df.dtypes
# Out:
# Order ID                    str
# Order Date       datetime64[us]
# Ship Date        datetime64[us]
# Ship Mode                   str
# Customer Name               str
# Segment                     str
# Country                     str
# City                        str
# Region                      str
# Category                    str
# Sub-Category                str
# Product Name                str
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df.to_csv("cleaned_superstore.csv", index=False)

# %%
df.head()
# Out:
#    Order ID Order Date  Ship Date       Ship Mode     Customer Name  \
# 0  ORD-1001 2024-01-13 2024-01-19  Standard Class    Margaret Brown
# 1  ORD-1002 2024-01-16 2024-01-17  Standard Class           Amy Lee
# 2  ORD-1003 2024-01-04 2024-01-11    Second Class      Kelly Nelson
# 3  ORD-1004 2024-06-25 2024-06-30    Second Class  Benjamin Jimenez
# 4  ORD-1005 2024-10-22 2024-10-24     First Class   Stephanie Green
#
#        Segment Country           City   Region         Category Sub-Category  \
# 0  Home Office   India   Patrickmouth     East       Technology       Laptop
# 1  Home Office   India       Penaport  Central  Office Supplies        Paper
# 2     Consumer   India       Loriberg     East  Office Supplies          Pen
# 3     Consumer   India  Nathanchester    South        Furniture     Bookcase
# 4     Consumer   India  North Cynthia     East       Technology      Printer
#
#          Product Name   Sales  Quantity  Discount  Profit
# ...
